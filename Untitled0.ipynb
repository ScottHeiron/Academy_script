# %% [markdown]
# <a href="https://colab.research.google.com/github/ScottHeiron/Academy_script/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#hello

# %%
# !pip install -q kaggle
from google.colab import files
files.upload()
#create a kaggle folder
# !mkdir ~/.kaggle
# Go on kaggle > Account > Create New API token
# Save the json file in your laptop in a dedicated folder
# copy the kaggle.json to folder created
# !cp kaggle.json ~/.kaggle
#permission for the json to act
# !chmod 600 ~/.kaggle/kaggle.json
# Datasets available here:
# https://www.kaggle.com/avikpaul4u/vehicle-loan-default-prediction
# !kaggle datasets download -d avikpaul4u/vehicle-loan-default-prediction
# !unzip vehicle-loan-default-prediction.zip
# https://www.kaggle.com/uciml/red-wine-quality-cortez-et-al-2009
# !kaggle datasets download -d uciml/red-wine-quality-cortez-et-al-2009
# !unzip red-wine-quality-cortez-et-al-2009.zip
# Out:
#      <input type="file" id="files-620ee623-af3a-4fd0-8776-42b19ec20e2b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-620ee623-af3a-4fd0-8776-42b19ec20e2b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# Downloading vehicle-loan-default-prediction.zip to /content
#   0% 0.00/11.6M [00:00<?, ?B/s]
# 100% 11.6M/11.6M [00:00<00:00, 146MB/s]
# Archive:  vehicle-loan-default-prediction.zip
#   inflating: Data Dictionary.xlsx
#   inflating: test.csv
#   inflating: train.csv
# Downloading red-wine-quality-cortez-et-al-2009.zip to /content
#   0% 0.00/25.6k [00:00<?, ?B/s]
# 100% 25.6k/25.6k [00:00<00:00, 21.1MB/s]
# Archive:  red-wine-quality-cortez-et-al-2009.zip
#   inflating: winequality-red.csv

# %%
7+3
7-3
7*3
21/2
21//2 #floor division
21%2 #modulo
21**2 #exponential
# Out:
# 441

# %%
a=3
b=4
b
a

#Running this section will run all bits of in the section but will give the last output given (in this case a and not b)
#If a = 10 elsewhere, running this will make a=3
# Out:
# 3

# %%
c=a+b

# %%
b=c-b

# %%
b
# Out:
# 3

# %%
c
# Out:
# 7

# %%
a
# Out:
# 3

# %%
b+C
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-a22f8f612632> in <module>()
# ----> 1 b+C
#
# NameError: name 'C' is not defined

# %%
a=10 #Definition

# %%
a==10 #Comparison
# Out:
# True

# %%
a==9
a<=9
# Out:
# False

# %%
a<=3
a>3
# Out:
# True

# %%
#Variable names are case sensitive.
Beautiful_Variable = 3
beautiful_variable = 4
Beautiful_Variable
# Out:
# 3

# %%
cities = ['Paris','Zurich','Rome','Berlin','London']
cities
# Out:
# ['Paris', 'Zurich', 'Rome', 'Berlin', 'London']

# %%
type(cities)
# Out:
# list

# %%
cities[0]
#First element of a list is the 0th element
# Out:
# 'Paris'

# %%
cities[-2]
# minus will give the element from the end
# Out:
# 'Berlin'

# %%
cities[1]
# Out:
# 'Zurich'

# %%
cities[2]='Milan'
#Can easily update the (n+1)th element of a list
cities
# Out:
# ['Paris', 'Zurich', 'Milan', 'Berlin', 'London']

# %%
cities.insert(2,'HK')
print(cities)
#Inserts element in the 2nd position and pushes everything by 1
# Out:
# ['Paris', 'Zurich', 'HK', 'Milan', 'Berlin', 'London']

# %%
cities.append('Rio')
print(cities)
#Appends adds to the end
# Out:
# ['Paris', 'Zurich', 'HK', 'Milan', 'Berlin', 'London', 'Rio']

# %%
cities.remove('Paris')
print(cities)
#Removes first occurence of element to be removed
# Out:
# ['Zurich', 'HK', 'Milan', 'Berlin', 'London', 'Rio']

# %%
cities.insert(2,848)
print(cities)
cities.append(848)
print(cities)
#Using print, you can see multiple outputs in the same code
# Out:
# ['Zurich', 'HK', 848, 848, 'Milan', 'Berlin', 'London', 'Rio', 848]
# ['Zurich', 'HK', 848, 848, 'Milan', 'Berlin', 'London', 'Rio', 848, 848]

# %%
cities
# Out:
# ['Zurich', 'HK', 848, 'Milan', 'Berlin', 'London', 'Rio', 848]

# %%
Rome='Naples'
cities.insert(2,Rome)
print(cities)
# Out:
# ['Zurich', 'HK', 'Naples', 'Naples', 'Naples', 'Naples', 848, 848, 'Milan', 'Berlin', 'London', 'Rio', 848, 848]

# %%
cities.insert(2,Naples) #this would not work as Naples is treated as a variable which has not been defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-ae3198a60962> in <module>()
# ----> 1 cities.insert(2,Naples) #this would not work as Naples is treated as a variable which has not been defined
#
# NameError: name 'Naples' is not defined

# %%
seven=7
cities.insert(4,seven)
print(cities)
# Out:
# ['Zurich', 'HK', 'Naples', 'Naples', 7, 'Naples', 'Naples', 848, 848, 'Milan', 'Berlin', 'London', 'Rio', 848, 848]

# %%
cities.append("Dumont d'Urville") #Double quotes can take anything inside it, even single quotes such as the one in this statement - #'Dumont d'Urville' wouldn't be recognised in the function
print(cities.index("Dumont d'Urville")) #Finds where the element is
# Out:
# 1

# %%
val = -0
if val > 0:
  print('The value is positive')
elif val < 0:
  print('The value is negative')
else:
  print('It is zero')

#Can have as many elif as you need
# Out:
# It is zero

# %%
if 7 not in [0,1,2,3,4]:
  print('Indeed')
# Out:
# Indeed

# %%
a='1'
b='2'
if a is b:
  print('nice')

if a is not b:
  print('still nice')

  #Can use is to compare strings and values

  c=1
  d=1
  if c is d:
    print('crackin')
    
  if c is not d:
    print('still crackin')
# Out:
# still nice
# crackin

# %%
fruits = ['apple','pear','cherry']
for i in fruits:
  print(i)

  #Printing each element in the list
# Out:
# apple
# pear
# cherry

# %%
list_of_lists = [['a','b','c'],[1,2,3]]
list_of_lists

for sub_list in list_of_lists: #sub_list acts as a local variable within list_of_lists and doesn't need to be defined prior
  print("We treat the list: ",sub_list)

  for element in sub_list: #element acts as a local variable within sub_list
    print('We display the element: ',element)
# Out:
# We treat the list:  ['a', 'b', 'c']
# We display the element:  a
# We display the element:  b
# We display the element:  c
# We treat the list:  [1, 2, 3]
# We display the element:  1
# We display the element:  2
# We display the element:  3

# %%
length=87
width=54
area=length*width
area
# Out:
# 4698

# %%
def AREA(Length,Width): #Defining and using a function
  my_area=Length*Width
  return my_area

print(AREA(87,54))
print(AREA(55,5))
# Out:
# 4698
# 275

# %%
last_list = [1,2,3,4,5,888,6,7,888,8,9] #Removing all of a type of element

valueToBeRemoved = 888
last_list = [value for value in last_list if value != valueToBeRemoved]
print(last_list)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
import pandas as pd
#importing library name pandas as pd

import numpy as np
df = pd.read_csv('/content/winequality-red.csv')

# %%
df = pd.read_csv('/content/winequality-red.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.head()
#Gives first 5 of the table
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.head(12)
#Gives first 12 of the table
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4              0.70         0.00             1.9      0.076
# 1             7.8              0.88         0.00             2.6      0.098
# 2             7.8              0.76         0.04             2.3      0.092
# 3            11.2              0.28         0.56             1.9      0.075
# 4             7.4              0.70         0.00             1.9      0.076
# 5             7.4              0.66         0.00             1.8      0.075
# 6             7.9              0.60         0.06             1.6      0.069
# 7             7.3              0.65         0.00             1.2      0.065
# 8             7.8              0.58         0.02             2.0      0.073
# 9             7.5              0.50         0.36             6.1      0.071
# 10            6.7              0.58         0.08             1.8      0.097
# 11            7.5              0.50         0.36             6.1      0.071
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  11.0                  34.0   0.9978  3.51       0.56
# 1                  25.0                  67.0   0.9968  3.20       0.68
# 2                  15.0                  54.0   0.9970  3.26       0.65
# 3                  17.0                  60.0   0.9980  3.16       0.58
# 4                  11.0                  34.0   0.9978  3.51       0.56
# 5                  13.0                  40.0   0.9978  3.51       0.56
# 6                  15.0                  59.0   0.9964  3.30       0.46
# 7                  15.0                  21.0   0.9946  3.39       0.47
# 8                   9.0                  18.0   0.9968  3.36       0.57
# 9                  17.0                 102.0   0.9978  3.35       0.80
# 10                 15.0                  65.0   0.9959  3.28       0.54
# 11                 17.0                 102.0   0.9978  3.35       0.80
#
#     alcohol  quality
# 0       9.4        5
# 1       9.8        5
# 2       9.8        5
# 3       9.8        6
# 4       9.4        5
# 5       9.4        5
# 6       9.4        5
# 7      10.0        7
# 8       9.5        7
# 9      10.5        5
# 10      9.2        5
# 11     10.5        5

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1591                 16.0                  26.0  0.99402  3.67       0.56
# 1592                 29.0                  40.0  0.99574  3.42       0.75
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1591     11.6        6
# 1592     11.0        6
# 1593      9.5        6
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6

# %%
df.tail(8)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1591                 16.0                  26.0  0.99402  3.67       0.56
# 1592                 29.0                  40.0  0.99574  3.42       0.75
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1591     11.6        6
# 1592     11.0        6
# 1593      9.5        6
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6

# %%
df.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 361             8.6              0.45         0.31             2.6      0.086
# 522             8.2              0.39         0.49             2.3      0.099
# 1540            6.2              0.52         0.08             4.4      0.071
# 1060           11.6              0.23         0.57             1.8      0.074
# 1503            6.2              0.44         0.39             2.5      0.077
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 361                  21.0                  50.0  0.99820  3.37       0.91
# 522                  47.0                 133.0  0.99790  3.38       0.99
# 1540                 11.0                  32.0  0.99646  3.56       0.63
# 1060                  3.0                   8.0  0.99810  3.14       0.70
# 1503                  6.0                  14.0  0.99555  3.51       0.69
#
#       alcohol  quality
# 361       9.9        6
# 522       9.8        5
# 1540     11.6        6
# 1060      9.9        6
# 1503     11.0        6

# %%
df.sample(8,random_state=77777)
#Random state gives same random numbers every time
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 474            10.5             0.280         0.51             1.7      0.080
# 208             7.8             0.440         0.28             2.7      0.100
# 1237            7.1             0.750         0.01             2.2      0.059
# 620             8.3             0.540         0.24             3.4      0.076
# 1475            5.3             0.470         0.11             2.2      0.048
# 187             7.7             0.705         0.10             2.6      0.084
# 1379            7.5             0.570         0.02             2.6      0.077
# 759             8.8             0.420         0.21             2.5      0.092
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 474                  10.0                  24.0  0.99820  3.20       0.89
# 208                  18.0                  95.0  0.99660  3.22       0.67
# 1237                 11.0                  18.0  0.99242  3.39       0.40
# 620                  16.0                 112.0  0.99760  3.27       0.61
# 1475                 16.0                  89.0  0.99182  3.54       0.88
# 187                   9.0                  26.0  0.99760  3.39       0.49
# 1379                 11.0                  35.0  0.99557  3.36       0.62
# 759                  33.0                  88.0  0.99823  3.19       0.52
#
#         alcohol  quality
# 474    9.400000        6
# 208    9.400000        5
# 1237  12.800000        6
# 620    9.400000        5
# 1475  13.566667        7
# 187    9.700000        5
# 1379  10.800000        6
# 759    9.200000        5

# %%
df.dtypes
#shows data types of the table
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.describe()
#Gives some statistics of the dataset
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
df.info()
#Gives some other info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.shape
# Out:
# (1599, 12)

# %%
len(df)
# Out:
# 1599

# %%
df['fixed acidity'].head()
#Only one square bracket for one element
# Out:
# 0     7.4
# 1     7.8
# 2     7.8
# 3    11.2
# 4     7.4
# Name: fixed acidity, dtype: float64

# %%
df[['fixed acidity','volatile acidity']].head()
# Out:
#    fixed acidity  volatile acidity
# 0            7.4              0.70
# 1            7.8              0.88
# 2            7.8              0.76
# 3           11.2              0.28
# 4            7.4              0.70

# %%
df[['fixed acidity','volatile acidity','quality']].head()
#2 square brackets for more than one
# Out:
#    fixed acidity  volatile acidity  quality
# 0            7.4              0.70        5
# 1            7.8              0.88        5
# 2            7.8              0.76        5
# 3           11.2              0.28        6
# 4            7.4              0.70        5

# %%
df['fixed acidity']>7
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596    False
# 1597    False
# 1598    False
# Name: fixed acidity, Length: 1599, dtype: bool

# %%
mask1 = df['fixed acidity']>7

# %%
mask1
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596    False
# 1597    False
# 1598    False
# Name: fixed acidity, Length: 1599, dtype: bool

# %%
df[mask1]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1576            8.0              0.30         0.63             1.6      0.081
# 1580            7.4              0.35         0.33             2.4      0.068
# 1585            7.2              0.39         0.44             2.6      0.066
# 1586            7.5              0.31         0.41             2.4      0.065
# 1588            7.2              0.66         0.33             2.5      0.068
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1576                 16.0                  29.0  0.99588  3.30       0.78
# 1580                  9.0                  26.0  0.99470  3.36       0.60
# 1585                 22.0                  48.0  0.99494  3.30       0.84
# 1586                 34.0                  60.0  0.99492  3.34       0.85
# 1588                 34.0                 102.0  0.99414  3.27       0.78
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1576     10.8        6
# 1580     11.9        6
# 1585     11.5        6
# 1586     11.4        6
# 1588     12.8        6
#
# [1237 rows x 12 columns]

# %%
df[mask1].min()
# Out:
# fixed acidity           7.10000
# volatile acidity        0.12000
# citric acid             0.00000
# residual sugar          0.90000
# chlorides               0.03800
# free sulfur dioxide     1.00000
# total sulfur dioxide    6.00000
# density                 0.99007
# pH                      2.74000
# sulphates               0.33000
# alcohol                 8.40000
# quality                 3.00000
# dtype: float64

# %%
temp = df[mask1]

# %%
df['fixed acidity'].between(7,8)
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596    False
# 1597    False
# 1598    False
# Name: fixed acidity, Length: 1599, dtype: bool

# %%
mask2=df['fixed acidity'].between(7,8)

# %%
temp=df[mask2][['pH','quality']]

# %%
temp.head()
# Out:
#      pH  quality
# 0  3.51        5
# 1  3.20        5
# 2  3.26        5
# 4  3.51        5
# 5  3.51        5

# %%
df[mask2][['pH','quality']].sample(n=100,random_state=893717398).nunique()
# Out:
# pH         42
# quality     4
# dtype: int64

# %%
mask3 = (((df['residual sugar']>=2.3) | (df['residual sugar'] <= 1.9)) & (df['sulphates'] < 0.7301))
temp = df[mask3]
temp
# Filtering for the following data
# | means OR
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1582            6.1             0.715         0.10             2.6      0.053
# 1587            5.8             0.610         0.11             1.8      0.066
# 1589            6.6             0.725         0.20             7.8      0.073
# 1591            5.4             0.740         0.09             1.7      0.089
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1582                 13.0                  27.0  0.99362  3.57       0.50
# 1587                 18.0                  28.0  0.99483  3.55       0.66
# 1589                 29.0                  79.0  0.99770  3.29       0.54
# 1591                 16.0                  26.0  0.99402  3.67       0.56
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1582     11.9        5
# 1587     10.9        6
# 1589      9.2        5
# 1591     11.6        6
# 1598     11.0        6
#
# [893 rows x 12 columns]

# %%
mask3
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596    False
# 1597    False
# 1598     True
# Length: 1599, dtype: bool

# %%
df[mask3].describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count     893.000000        893.000000   893.000000      893.000000
# mean        8.166181          0.551013     0.240862        2.663942
# std         1.637488          0.176767     0.188316        1.512533
# min         4.700000          0.160000     0.000000        0.900000
# 25%         7.100000          0.420000     0.080000        1.800000
# 50%         7.800000          0.550000     0.220000        2.400000
# 75%         9.000000          0.660000     0.390000        2.800000
# max        15.600000          1.330000     0.780000       15.500000
#
#         chlorides  free sulfur dioxide  total sulfur dioxide     density  \
# count  893.000000           893.000000            893.000000  893.000000
# mean     0.082759            15.787234             47.243001    0.996726
# std      0.026202            10.343299             34.579307    0.001889
# min      0.012000             3.000000              6.000000    0.990070
# 25%      0.071000             7.000000             21.000000    0.995600
# 50%      0.080000            14.000000             38.000000    0.996800
# 75%      0.089000            21.000000             65.000000    0.997870
# max      0.387000            72.000000            289.000000    1.003200
#
#                pH   sulphates     alcohol     quality
# count  893.000000  893.000000  893.000000  893.000000
# mean     3.325969    0.586439   10.353210    5.530795
# std      0.148147    0.074673    1.024548    0.756440
# min      2.880000    0.330000    8.500000    3.000000
# 25%      3.220000    0.540000    9.500000    5.000000
# 50%      3.320000    0.590000   10.100000    5.000000
# 75%      3.410000    0.640000   11.000000    6.000000
# max      4.010000    0.730000   13.600000    8.000000

# %%
len(df[mask3])
# Out:
# 893

# %%
df[mask3]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1582            6.1             0.715         0.10             2.6      0.053
# 1587            5.8             0.610         0.11             1.8      0.066
# 1589            6.6             0.725         0.20             7.8      0.073
# 1591            5.4             0.740         0.09             1.7      0.089
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1582                 13.0                  27.0  0.99362  3.57       0.50
# 1587                 18.0                  28.0  0.99483  3.55       0.66
# 1589                 29.0                  79.0  0.99770  3.29       0.54
# 1591                 16.0                  26.0  0.99402  3.67       0.56
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1582     11.9        5
# 1587     10.9        6
# 1589      9.2        5
# 1591     11.6        6
# 1598     11.0        6
#
# [893 rows x 12 columns]

# %%
def citric_acid_cat(x):
  if x < 0.21:
    return 'A'
  elif x < 0.3:
    return 'B'
  else:
    return 'C'

# %%
df['NEW_NAME_citric_cat'] = df['citric acid'].apply(lambda x: citric_acid_cat(x))

# %%
df['NEW_NAME_citric_cat']
# Out:
# 0       A
# 1       A
# 2       A
# 3       C
# 4       A
#        ..
# 1594    A
# 1595    A
# 1596    A
# 1597    A
# 1598    C
# Name: NEW_NAME_citric_cat, Length: 1599, dtype: object

# %%
df['NEW_NAME_citric_cat'].sample(5)
# Out:
# 685    B
# 823    A
# 537    B
# 816    A
# 51     A
# Name: NEW_NAME_citric_cat, dtype: object

# %%
df = df.drop(columns=['NEW_NAME_citric_cat'])

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
mask5 = (((df['residual sugar'] >= 2.3) | (df['residual sugar'] <= 1.9)) & (df['sulphates'] < 0.7301) & (df['citric acid'] != 'A'))

# %%
df[mask5]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1582            6.1             0.715         0.10             2.6      0.053
# 1587            5.8             0.610         0.11             1.8      0.066
# 1589            6.6             0.725         0.20             7.8      0.073
# 1591            5.4             0.740         0.09             1.7      0.089
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1582                 13.0                  27.0  0.99362  3.57       0.50
# 1587                 18.0                  28.0  0.99483  3.55       0.66
# 1589                 29.0                  79.0  0.99770  3.29       0.54
# 1591                 16.0                  26.0  0.99402  3.67       0.56
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1582     11.9        5
# 1587     10.9        6
# 1589      9.2        5
# 1591     11.6        6
# 1598     11.0        6
#
# [893 rows x 12 columns]

# %%
lst_cat_to_keep = ['A','B','P','W']

# %%
mask6 = ((df['sulphates'] < 0.7301) & (df['citric acid'].isin(lst_cat_to_keep)))

# %%
mask6
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1594    False
# 1595    False
# 1596    False
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %%
df[mask6]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
df['Y'] = np.where(df['quality']>7, 1, 0)

# %%
df['Y']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: Y, Length: 1599, dtype: int64

# %%
df['Y2'] = np.where(df['quality']>7, 1, df['quality'])

# %%
df['Y2']
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: Y2, Length: 1599, dtype: int64

# %%
df.sample(n=5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 263             7.9             0.370         0.23            1.80      0.077
# 399             8.7             0.765         0.22            2.30      0.064
# 1002            9.1             0.290         0.33            2.05      0.063
# 542             9.3             0.715         0.24            2.10      0.070
# 359            12.6             0.380         0.66            2.60      0.088
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 263                  23.0                  49.0  0.99630  3.28       0.67
# 399                   9.0                  42.0  0.99630  3.10       0.55
# 1002                 13.0                  27.0  0.99516  3.26       0.84
# 542                   5.0                  20.0  0.99660  3.12       0.59
# 359                  10.0                  41.0  1.00100  3.17       0.68
#
#       alcohol  quality  Y  Y2
# 263       9.3        5  0   5
# 399       9.4        5  0   5
# 1002     11.7        7  0   7
# 542       9.9        5  0   5
# 359       9.8        6  0   6
